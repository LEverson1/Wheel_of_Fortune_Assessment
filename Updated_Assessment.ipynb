# %%
# Out:
# =====Welcome to Wheel of Fortune!=====
# ...
# Please input the names of your players!
# Player 1 Name: Luke
# Player 2 Name: Denver
# Player 3 Name: Marshall
#
# Welcome to the game Luke, Denver, and Marshall!
#
# =====Welcome to Round 1!=====
# ...
#
# The Category for Round 1 is: Sports
#
# The phrase is 1 word long!
# The word has 8 letters!
#
# Luke you are first!
# Would you like to spin the wheel? yes/no: yes
# You stand to win $ 150
# Would you like to guess the phrase? yes/no: no
# Guessed Letters:  []
# Guess a consonant: z
# Previous Guesses: ['z']
# _
# _
# _
# _
# _
# _
# _
# _
# Incorrect
#
# Denver it is your turn!
# Would you like to spin the wheel? yes/no: yes
# You stand to win $ 150
# Would you like to guess the phrase? yes/no: no
# Guessed Letters:  ['z']
# Guess a consonant: q
# Previous Guesses: ['z', 'q']
# _
# _
# _
# _
# _
# _
# _
# _
# Incorrect
#
# Marshall it is your turn!
# Would you like to spin the wheel? yes/no: yes
# You stand to win $ 150
# ...

# %%
def spin_the_wheel():
    spin_result = ""
    i = random.randint(1,25)
    try:
        if i == 24:
            spin_result = 'Bankrupt!'
            return spin_result
        elif i == 23:
            spin_result = 'Lose a Turn!'
            return spin_result
        else:
            spin_result = 50*i
            return spin_result
    except:
        print("An error has occured")

spin_result = spin_the_wheel()
print(spin_result)
# Out:
# 750

# %%
phrase1 = ("baseball")
round_one_hint = ("Sports")

phrase2 = ("divergent")
round_two_hint = ("Book Titles")

phrase3 = ("broccoli")
round_three_hint = ("Food & Drink")

# Break the phrases down into lists

list_of_letters1 = list(phrase1)
list_of_letters2 = list(phrase2)
list_of_letters3 = list(phrase3)
print(list_of_letters1)
# Out:
# ['b', 'a', 's', 'e', 'b', 'a', 'l', 'l']

# %%
buying_vowel = True
                                while buying_vowel:
                                    buy_vowel_choice1 = input("Would you like to buy a vowel for $250? yes/no: ")
                                    if buy_vowel_choice1 == "yes":
                                        bank1 -= 250
                                        p1_vowel_guess1 = input("Guess a vowel!: ")
                                        if p1_vowel_guess1 in guess_list1:
                                            print("That was already guessed!")
                                            p1_vowel_guess1 = input("Guess a vowel!: ")
                                        guess_list1.append(p1_vowel_guess1)
                                        while not p1_vowel_guess1.isalpha():
                                            print("Please enter a letter, not a number")
                                            p1_vowel_guess1 = input("Guess a vowel!: ")
                                        guesses1 += p1_vowel_guess1
                                        for char in list_of_letters1:
                                            if char in guesses1:
                                                print(char)
                                            else:
                                                print("_")
                                                player1_turn = False
                                                break
                                    else:
                                        would_guess1 = input("Would you like to guess the phrase? yes/no: ")
                                        if would_guess1 == "yes":
                                            full_guess1 = input("Guess the full phrase here!: ")
                                            if full_guess1 == phrase1:
                                                print()
                                                print("Congrats, you guessed the phrase!")
                                                print()
                                                print("That's the end of round 1!")
                                                round_1 = False
                                                break
                                        else:
                                            player1_turn = False

# %%
buying_vowel = True
                                while buying_vowel:
                                    buy_vowel_choice2 = input("Would you like to buy a vowel for $250? yes/no: ")
                                    if buy_vowel_choice2 == "yes":
                                        bank2 -= 250
                                        p2_vowel_guess1 = input("Guess a vowel!: ")
                                        if p2_vowel_guess1 in guess_list1:
                                            print("That was already guessed!")
                                            p2_vowel_guess1 = input("Guess a vowel!: ")
                                        guess_list1.append(p2_vowel_guess1)
                                        while not p2_vowel_guess1.isalpha():
                                            print("Please enter a letter, not a number")
                                            p2_vowel_guess1 = input("Guess a vowel!: ")
                                        guesses1 += p2_vowel_guess1
                                        for char in list_of_letters1:
                                            if char in guesses1:
                                                print(char)
                                            else:
                                                print("_")
                                                player2_turn = False
                                    else:
                                        would_guess2 = input("Would you like to guess the phrase? yes/no: ")
                                        if would_guess2 == "yes":
                                            full_guess2 = input("Guess the full phrase here!: ")
                                            if full_guess2 == phrase1:
                                                print()
                                                print("Congrats, you guessed the phrase!")
                                                print()
                                                print("That's the end of round 1!")
                                                round_1 = False
                                                break
                                        else:
                                            player2_turn = False

# %%
# Final Wheel of Fortune Game
# Run this Chunk to Play the Game
# Introduce them to the game and input player names
print("=====Welcome to Wheel of Fortune!=====")
print("======================================")
print("Please input the names of your players!")
Player1 = input("Player 1 Name: ")
Player2 = input("Player 2 Name: ")
Player3 = input("Player 3 Name: ")
print()
print(f"Welcome to the game",Player1 + ",",Player2 + ", and",Player3 + "!")

# Create a list of vowels
vowel_list = ['a','e','i','o','u']

# Input the words for each round
phrase1 = ("baseball")
round_one_hint = ("Sports")

phrase2 = ("divergent")
round_two_hint = ("Book Titles")

phrase3 = ("broccoli")
round_three_hint = ("Food & Drink")

# Break the phrases down into lists

list_of_letters1 = list(phrase1)
list_of_letters2 = list(phrase2)
list_of_letters3 = list(phrase3)

# Create Banks for each of the players
bank1 = 0
bank2 = 0
bank3 = 0

# Create a reusable function to spin the wheel
import random

def spin_the_wheel():
    spin_result = ""
    i = random.randint(1,24)
    try:
        if i == 24:
            spin_result = 'Bankrupt!'
            return spin_result
        elif i == 23:
            spin_result = 'Lose a Turn!'
            return spin_result
        else:
            spin_result = 50*i
            return spin_result
    except:
        print("An error has occured")
# Begin the game
play = True

while play:
    # Begin Round 1
    round_1 = True
    while round_1 and play:
        guess_list1 = []
        guesses1 = ''
        print()
        print("=====Welcome to Round 1!=====")
        print("=============================")
        print()
        print("The Category for Round 1 is: Sports")
        print()
        print("The phrase is 1 word long!")
        print("The word has 8 letters!")
        print()
        player_turns1 = True
        while player_turns1 and round_1:
            player1_turn = True
            while player1_turn and round_1:
                print()
                print(Player1,"it is your turn!")
                spin = input("Would you like to spin the wheel? yes/no: ")
                if spin == "yes":
                    spin_the_wheel()
                    spin_result1 = spin_the_wheel()
                    if spin_result1 == "Bankrupt!":
                        print()
                        print("Bankrupt!")
                        bank1 = 0
                        player1_turn = False
                    elif spin_result1 == "Lose a Turn!":
                        print()
                        print("Lose a Turn!")
                        player1_turn = False
                    else:
                        print(f"You stand to win $",spin_result1)
                        would_guess1 = input("Would you like to guess the phrase? yes/no: ")
                        if would_guess1 == "yes":
                            full_guess1 = input("Guess the full phrase here!: ")
                            if full_guess1 == phrase1:
                                bank1 += spin_result1
                                print()
                                print("Congrats, you guessed the phrase!")
                                print()
                                print("That's the end of round 1!")
                                round_1 = False
                                break
                        else:
                            print("Guessed Letters: ",guess_list1)
                            p1_consonant_guess = input("Guess a consonant: ") 
                            if p1_consonant_guess in guess_list1:
                                print("That was already guessed!")
                                p1_consonant_guess = input("Guess a consonant: ")
                            elif p1_consonant_guess in vowel_list:
                                print("That's a vowel! Please enter a consonant!")
                                p1_consonant_guess = input("Guess a consonant: ")
                            guess_list1.append(p1_consonant_guess)
                            print("Previous Guesses:", guess_list1)
                            while not p1_consonant_guess.isalpha():
                                print("Please enter a letter, not a number")
                                p1_consonant_guess = input("Guess a consonant: ")
                            guesses1 += p1_consonant_guess
                            for char in list_of_letters1:
                                if char in guesses1:
                                    print(char)
                                    bank1 += spin_result1  
                                else:
                                    print("_")
                            if p1_consonant_guess in list_of_letters1:
                                buying_vowel = True
                                while buying_vowel:
                                    print()
                                    print("Guessed Letters: ",guess_list1)
                                    buy_vowel_choice1 = input("Would you like to buy a vowel for $250? yes/no: ")
                                    if buy_vowel_choice1 == "yes":
                                        if bank1 < 250:
                                            print()
                                            print("You can't afford a vowel!")
                                        else:
                                            bank1 -= 250
                                            p1_vowel_guess1 = input("Guess a vowel!: ")
                                            if p1_vowel_guess1 in guess_list1:
                                                print("That was already guessed!")
                                                p1_vowel_guess1 = input("Guess a vowel!: ")
                                            elif p1_vowel_guess1 not in vowel_list:
                                                print("That's not a vowel!")
                                                p1_vowel_guess1 = input("Guess a vowel!: ")
                                            guess_list1.append(p1_vowel_guess1)
                                            while not p1_vowel_guess1.isalpha():
                                                print("Please enter a letter, not a number")
                                                p1_vowel_guess1 = input("Guess a vowel!: ")
                                            guesses1 += p1_vowel_guess1
                                            for char in list_of_letters1:
                                                if char in guesses1:
                                                    print(char)
                                                else:
                                                    print("_")
                                            if p1_vowel_guess1 in list_of_letters1:
                                                print()
                                                print("Correct!")
                                                print()
                                            else:
                                                print()
                                                print("Incorrect")
                                                player1_turn = False
                                    else:
                                        would_guess1 = input("Would you like to guess the phrase? yes/no: ")
                                        if would_guess1 == "yes":
                                            full_guess1 = input("Guess the full phrase here!: ")
                                            if full_guess1 == phrase1:
                                                print()
                                                print("Congrats, you guessed the phrase!")
                                                print()
                                                print("That's the end of round 1!")
                                                buying_vowel = False
                                                round_1 = False
                                        else:
                                            buying_vowel = False
                                            player1_turn = False
                                            break
                            else:
                                print("Incorrect")
                                player1_turn = False
                                break
                else:
                    print("Please spin the wheel!")
            player2_turn = True
            while player2_turn and round_1:
                print()
                print(Player2,"it is your turn!")
                spin = input("Would you like to spin the wheel? yes/no: ")
                if spin == "yes":
                    spin_the_wheel()
                    spin_result2 = spin_the_wheel()
                    if spin_result2 == "Bankrupt!":
                        print()
                        print("Bankrupt!")
                        bank2 = 0
                        player2_turn = False
                    elif spin_result2 == "Lose a Turn!":
                        print()
                        print("Lose a Turn!")
                        player2_turn = False
                    else:
                        print("You stand to win $",spin_result2)
                        would_guess2 = input("Would you like to guess the phrase? yes/no: ")
                        if would_guess2 == "yes":
                            full_guess2 = input("Guess the full phrase here!: ")
                            if full_guess2 == phrase1:
                                bank2 += spin_result2
                                print()
                                print("Congrats, you guessed the phrase!")
                                print()
                                print("That's the end of round 1!")
                                round_1 = False
                                break
                        else:
                            print("Guessed Letters: ",guess_list1)
                            p2_consonant_guess = input("Guess a consonant: ")
                            if p2_consonant_guess in guess_list1:
                                print("That was already guessed!")
                                p2_consonant_guess = input("Guess a consonant: ")
                            elif p2_consonant_guess in vowel_list:
                                print("That's a vowel! Please enter a consonant!")
                                p2_consonant_guess = input("Guess a consonant: ")
                            guess_list1.append(p2_consonant_guess)
                            print("Previous Guesses:",guess_list1)
                            while not p2_consonant_guess.isalpha():
                                print("Please enter a letter, not a number")
                                p2_consonant_guess = input("Guess a consonant: ")
                            guesses1 += p2_consonant_guess
                            for char in list_of_letters1:
                                if char in guesses1:
                                    print(char)
                                    bank2 += spin_result2  
                                else:
                                    print("_")
                            if p2_consonant_guess in list_of_letters1:
                                buying_vowel = True
                                while buying_vowel:
                                    print()
                                    print("Guessed Letters: ",guess_list1)
                                    buy_vowel_choice2 = input("Would you like to buy a vowel for $250? yes/no: ")
                                    if buy_vowel_choice2 == "yes":
                                        if bank2 < 250:
                                            print()
                                            print("You can't afford a vowel!")
                                        else:
                                            bank2 -= 250
                                            p2_vowel_guess1 = input("Guess a vowel!: ")
                                            if p2_vowel_guess1 in guess_list1:
                                                print("That was already guessed!")
                                                p2_vowel_guess1 = input("Guess a vowel!: ")
                                            elif p2_vowel_guess1 not in vowel_list:
                                                print("That's not a vowel!")
                                                p2_vowel_guess1 = input("Guess a vowel!: ")
                                            guess_list1.append(p2_vowel_guess1)
                                            while not p2_vowel_guess1.isalpha():
                                                print("Please enter a letter, not a number")
                                                p2_vowel_guess1 = input("Guess a vowel!: ")
                                            guesses1 += p2_vowel_guess1
                                            for char in list_of_letters1:
                                                if char in guesses1:
                                                    print(char)
                                                else:
                                                    print("_")
                                            if p2_vowel_guess1 in list_of_letters1:
                                                print()
                                                print("Correct!")
                                                print()
                                            else:
                                                print()
                                                print("Incorrect")
                                                player2_turn = False
                                    else:
                                        would_guess2 = input("Would you like to guess the phrase? yes/no: ")
                                        if would_guess2 == "yes":
                                            full_guess2 = input("Guess the full phrase here!: ")
                                            if full_guess2 == phrase1:
                                                print()
                                                print("Congrats, you guessed the phrase!")
                                                print()
                                                print("That's the end of round 1!")
                                                buying_vowel = False
                                                round_1 = False
                                        else:
                                            buying_vowel = False
                                            player2_turn = False
                                            break
                            else:
                                print("Incorrect")
                                player2_turn = False
                else:
                    print("Please spin the wheel!")
            player3_turn = True
            while player3_turn and round_1:
                print()
                print(Player3,"it is your turn!")
                spin = input("Would you like to spin the wheel? yes/no: ")
                if spin == "yes":
                    spin_the_wheel()
                    spin_result3 = spin_the_wheel()
                    if spin_result3 == "Bankrupt!":
                        print()
                        print("Bankrupt!")
                        bank3 = 0
                        player3_turn = False
                    elif spin_result3 == "Lose a Turn!":
                        print()
                        print("Lose a Turn!")
                        player3_turn = False
                    else:
                        print("You stand to win $",spin_result3)
                        would_guess3 = input("Would you like to guess the phrase? yes/no: ")
                        if would_guess3 == "yes":
                            full_guess3 = input("Guess the full phrase here!: ")
                            if full_guess3 == phrase1:
                                bank3 += spin_result3
                                print()
                                print("Congrats, you guessed the phrase!")
                                print()
                                print("That's the end of round 1!")
                                round_1 = False
                                break
                        else:
                            print("Guessed Letters: ",guess_list1)
                            p3_consonant_guess = input("Guess a consonant: ")
                            if p3_consonant_guess in guess_list1:
                                print("That was already guessed!")
                                p3_consonant_guess = input("Guess a consonant: ")
                            elif p3_consonant_guess in vowel_list:
                                print("That's a vowel! Please enter a consonant!")
                                p3_consonant_guess = input("Guess a consonant: ")
                            guess_list1.append(p3_consonant_guess)
                            print("Previous Guesses:",guess_list1)
                            while not p3_consonant_guess.isalpha():
                                print("Please enter a letter, not a number")
                                p3_consonant_guess = input("Guess a consonant: ")
                            guesses1 += p3_consonant_guess
                            for char in list_of_letters1:
                                if char in guesses1:
                                    print(char)
                                    bank3 += spin_result3  
                                else:
                                    print("_")
                            if p3_consonant_guess in list_of_letters1:
                                buying_vowel = True
                                while buying_vowel:
                                    print()
                                    print("Guessed Letters: ",guess_list1)
                                    buy_vowel_choice3 = input("Would you like to buy a vowel for $250? yes/no: ")
                                    if buy_vowel_choice3 == "yes":
                                        if bank3 < 250:
                                            print()
                                            print("You can't afford a vowel!")
                                        else:
                                            bank3 -= 250
                                            p3_vowel_guess1 = input("Guess a vowel!: ")
                                            if p3_vowel_guess1 in guess_list1:
                                                print("That was already guessed!")
                                                p3_vowel_guess1 = input("Guess a vowel!: ")
                                            elif p3_vowel_guess1 not in vowel_list:
                                                print("That's not a vowel!")
                                                p3_vowel_guess1 = input("Guess a vowel!: ")
                                            guess_list1.append(p3_vowel_guess1)
                                            while not p3_vowel_guess1.isalpha():
                                                print("Please enter a letter, not a number")
                                                p3_vowel_guess1 = input("Guess a vowel!: ")
                                            guesses1 += p3_vowel_guess1
                                            for char in list_of_letters1:
                                                if char in guesses1:
                                                    print(char)
                                                else:
                                                    print("_")
                                            if p3_vowel_guess1 in list_of_letters1:
                                                print()
                                                print("Correct!")
                                                print()
                                            else:
                                                print()
                                                print("Incorrect")
                                                player3_turn = False
                                    else:
                                        would_guess3 = input("Would you like to guess the phrase? yes/no: ")
                                        if would_guess3 == "yes":
                                            full_guess3 = input("Guess the full phrase here!: ")
                                            if full_guess3 == phrase1:
                                                print()
                                                print("Congrats, you guessed the phrase!")
                                                print()
                                                print("That's the end of round 1!")
                                                buying_vowel = False
                                                round_1 = False
                                        else:
                                            buying_vowel = False
                                            player3_turn = False
                                            break
                            else:
                                print("Incorrect")
                                player3_turn = False
                else:
                    print("Please spin the wheel!")
    round_2 = True
    while round_2 and play:
        guess_list2 = []
        guesses2 = ''
        print()
        print("=====Welcome to Round 2=====")
        print("============================")
        print()
        print("Let's take a look at the scores!")
        print(Player1,"has",bank1)
        print(Player2,"has",bank2)
        print(Player3,"has",bank3)
        print()
        print("The Category for Round 2 is: Book Titles")
        print()
        print("The phrase is 1 word long!")
        print("The word has 9 letters!")
        print()
        player_turns2 = True
        while player_turns2 and round_2:
            player1_turn = True
            while player1_turn and round_2:
                print(Player1,"it is your turn!")
                spin = input("Would you like to spin the wheel? yes/no: ")
                if spin == "yes":
                    spin_the_wheel()
                    spin_result4 = spin_the_wheel()
                    if spin_result4 == "Bankrupt!":
                        print()
                        print("Bankrupt!")
                        bank1 = 0
                        player1_turn = False
                    elif spin_result4 == "Lose a Turn!":
                        print("Lose a Turn")
                        player1_turn = False
                    else:
                        print("You stand to win $",spin_result4)
                        would_guess1 = input("Would you like to guess the phrase? yes/no: ")
                        if would_guess1 == "yes":
                            full_guess1 = input("Guess the full phrase here!: ")
                            if full_guess1 == phrase2:
                                bank1 += spin_result4
                                print()
                                print("Congrats, you guessed the phrase!")
                                print()
                                print("That's the end of round 2!")
                                round_2 = False
                                break
                        else:
                            print("Guessed Letters: ",guess_list2)
                            p1_consonant_guess = input("Guess a consonant: ")
                            if p1_consonant_guess in guess_list2:
                                print("That was already guessed!")
                                p1_consonant_guess = input("Guess a consonant: ")
                            elif p1_consonant_guess in vowel_list:
                                print("That's a vowel! Please enter a consonant!")
                                p1_consonant_guess = input("Guess a consonant: ")
                            guess_list2.append(p1_consonant_guess)
                            print("Previous Guesses:", guess_list2)
                            while not p1_consonant_guess.isalpha():
                                print("Please enter a letter, not a number")
                                p1_consonant_guess = input("Guess a consonant: ")
                            guesses2 += p1_consonant_guess
                            for char in list_of_letters2:
                                if char in guesses2:
                                    print(char)
                                    bank1 += spin_result4  
                                else:
                                    print("_")
                            if p1_consonant_guess in list_of_letters2:
                                buying_vowel = True
                                while buying_vowel:
                                    print()
                                    print("Guessed Letters: ",guess_list2)
                                    buy_vowel_choice1 = input("Would you like to buy a vowel for $250? yes/no: ")
                                    if buy_vowel_choice1 == "yes":
                                        if bank1 < 250:
                                            print()
                                            print("You can't afford a vowel!")
                                        else:
                                            bank1 -= 250
                                            p1_vowel_guess1 = input("Guess a vowel!: ")
                                            if p1_vowel_guess1 in guess_list2:
                                                print("That was already guessed!")
                                                p1_vowel_guess1 = input("Guess a vowel!: ")
                                            elif p1_vowel_guess1 not in vowel_list:
                                                print("That's not a vowel!")
                                                p1_vowel_guess1 = input("Guess a vowel!: ")
                                            guess_list2.append(p1_vowel_guess1)
                                            while not p1_vowel_guess1.isalpha():
                                                print("Please enter a letter, not a number")
                                                p1_vowel_guess1 = input("Guess a vowel!: ")
                                            guesses2 += p1_vowel_guess1
                                            for char in list_of_letters2:
                                                if char in guesses2:
                                                    print(char)
                                                else:
                                                    print("_")
                                            if p1_vowel_guess1 in list_of_letters2:
                                                print()
                                                print("Correct!")
                                                print()
                                            else:
                                                print()
                                                print("Incorrect")
                                                player1_turn = False
                                    else:
                                        would_guess1 = input("Would you like to guess the phrase? yes/no: ")
                                        if would_guess1 == "yes":
                                            full_guess1 = input("Guess the full phrase here!: ")
                                            if full_guess1 == phrase2:
                                                print()
                                                print("Congrats, you guessed the phrase!")
                                                print()
                                                print("That's the end of round 2!")
                                                buying_vowel = False
                                                round_2 = False
                                        else:
                                            buying_vowel = False
                                            player1_turn = False
                                            break
                            else:
                                print("Incorrect")
                                player1_turn = False
                                break
                else:
                    print("Please spin the wheel!")
            player2_turn = True
            while player2_turn and round_2:
                print()
                print(Player2,"it is your turn!")
                spin = input("Would you like to spin the wheel? yes/no: ")
                if spin == "yes":
                    spin_the_wheel()
                    spin_result5 = spin_the_wheel()
                    if spin_result5 == "Bankrupt!":
                        print()
                        print("Bankrupt!")
                        bank2 = 0
                        player2_turn = False
                    elif spin_result5 == "Lose a Turn!":
                        print("Lose a Turn!")
                        player2_turn = False
                    else:
                        print("You stand to win $",spin_result5)
                        would_guess2 = input("Would you like to guess the phrase? yes/no: ")
                        if would_guess2 == "yes":
                            full_guess2 = input("Guess the full phrase here!: ")
                            if full_guess2 == phrase2:
                                bank2 += spin_result5
                                print()
                                print("Congrats, you guessed the phrase!")
                                print()
                                print("That's the end of round 2!")
                                round_2 = False
                                break
                        else:
                            print("Guessed Letters: ",guess_list2)
                            p2_consonant_guess = input("Guess a consonant: ")
                            if p2_consonant_guess in guess_list2:
                                print("That was already guessed!")
                                p2_consonant_guess = input("Guess a consonant: ")
                            elif p2_consonant_guess in vowel_list:
                                print("That's a vowel! Please enter a consonant!")
                                p2_consonant_guess = input("Guess a consonant: ")
                            guess_list1.append(p2_consonant_guess)
                            print("Previous Guesses:",guess_list2)
                            while not p2_consonant_guess.isalpha():
                                print("Please enter a letter, not a number")
                                p2_consonant_guess = input("Guess a consonant: ")
                            guesses2 += p2_consonant_guess
                            for char in list_of_letters2:
                                if char in guesses2:
                                    print(char)
                                    bank2 += spin_result5  
                                else:
                                    print("_")
                            if p2_consonant_guess in list_of_letters2:
                                buying_vowel = True
                                while buying_vowel:
                                    print()
                                    print("Guessed Letters: ",guess_list2)
                                    buy_vowel_choice2 = input("Would you like to buy a vowel for $250? yes/no: ")
                                    if buy_vowel_choice2 == "yes":
                                        if bank2 < 250:
                                            print()
                                            print("You can't afford a vowel!")
                                        else:
                                            bank2 -= 250
                                            p2_vowel_guess1 = input("Guess a vowel!: ")
                                            if p2_vowel_guess1 in guess_list2:
                                                print("That was already guessed!")
                                                p2_vowel_guess1 = input("Guess a vowel!: ")
                                            elif p2_vowel_guess1 not in vowel_list:
                                                print("That's not a vowel!")
                                                p2_vowel_guess1 = input("Guess a vowel!: ")
                                            guess_list2.append(p2_vowel_guess1)
                                            while not p2_vowel_guess1.isalpha():
                                                print("Please enter a letter, not a number")
                                                p2_vowel_guess1 = input("Guess a vowel!: ")
                                            guesses2 += p2_vowel_guess1
                                            for char in list_of_letters2:
                                                if char in guesses2:
                                                    print(char)
                                                else:
                                                    print("_")
                                            if p2_vowel_guess1 in list_of_letters2:
                                                print()
                                                print("Correct!")
                                                print()
                                            else:
                                                print()
                                                print("Incorrect")
                                                player2_turn = False
                                    else:
                                        would_guess2 = input("Would you like to guess the phrase? yes/no: ")
                                        if would_guess2 == "yes":
                                            full_guess2 = input("Guess the full phrase here!: ")
                                            if full_guess2 == phrase2:
                                                print()
                                                print("Congrats, you guessed the phrase!")
                                                print()
                                                print("That's the end of round 2!")
                                                buying_vowel = False
                                                round_2 = False
                                        else:
                                            buying_vowel = False
                                            player2_turn = False
                                            break
                            else:
                                print("Incorrect")
                                player2_turn = False
                else:
                    print("Please spin the wheel!")
            player3_turn = True
            while player3_turn and round_2:
                print()
                print(Player3,"it is your turn!")
                spin = input("Would you like to spin the wheel? yes/no: ")
                if spin == "yes":
                    spin_the_wheel()
                    spin_result6 = spin_the_wheel()
                    if spin_result6 == "Bankrupt!":
                        print()
                        print("Bankrupt!")
                        bank3 = 0
                        player3_turn = False
                    elif spin_result6 == "Lose a Turn!":
                        print()
                        print("Lose a Turn!")
                        player3_turn = False
                    else:
                        print("You stand to win $",spin_result6)
                        would_guess3 = input("Would you like to guess the phrase? yes/no: ")
                        if would_guess3 == "yes":
                            full_guess3 = input("Guess the full phrase here!: ")
                            if full_guess3 == phrase2:
                                bank3 += spin_result6
                                print()
                                print("Congrats, you guessed the phrase!")
                                print()
                                print("That's the end of round 2!")
                                round_2 = False
                                break
                        else:
                            print("Guessed Letters: ",guess_list2)
                            p3_consonant_guess = input("Guess a consonant: ")
                            if p3_consonant_guess in guess_list2:
                                print("That was already guessed!")
                                p3_consonant_guess = input("Guess a consonant: ")
                            elif p3_consonant_guess in vowel_list:
                                print("That's a vowel! Please enter a consonant!")
                                p3_consonant_guess = input("Guess a consonant: ")
                            guess_list2.append(p3_consonant_guess)
                            print("Previous Guesses:",guess_list2)
                            while not p3_consonant_guess.isalpha():
                                print("Please enter a letter, not a number")
                                p3_consonant_guess = input("Guess a consonant: ")
                            guesses2 += p3_consonant_guess
                            for char in list_of_letters2:
                                if char in guesses2:
                                    print(char)
                                    bank3 += spin_result6  
                                else:
                                    print("_")
                            if p3_consonant_guess in list_of_letters2:
                                buying_vowel = True
                                while buying_vowel:
                                    print()
                                    print("Guessed Letters: ",guess_list2)
                                    buy_vowel_choice3 = input("Would you like to buy a vowel for $250? yes/no: ")
                                    if buy_vowel_choice3 == "yes":
                                        if bank1 < 250:
                                            print()
                                            print("You can't afford a vowel!")
                                        else:
                                            bank3 -= 250
                                            p3_vowel_guess1 = input("Guess a vowel!: ")
                                            if p3_vowel_guess1 in guess_list2:
                                                print("That was already guessed!")
                                                p3_vowel_guess1 = input("Guess a vowel!: ")
                                            elif p3_vowel_guess1 not in vowel_list:
                                                print("That's not a vowel!")
                                                p3_vowel_guess1 = input("Guess a vowel!: ")
                                            guess_list2.append(p3_vowel_guess1)
                                            while not p3_vowel_guess1.isalpha():
                                                print("Please enter a letter, not a number")
                                                p3_vowel_guess1 = input("Guess a vowel!: ")
                                            guesses2 += p3_vowel_guess1
                                            for char in list_of_letters2:
                                                if char in guesses2:
                                                    print(char)
                                                else:
                                                    print("_")
                                            if p3_vowel_guess1 in list_of_letters2:
                                                print()
                                                print("Correct!")
                                                print()
                                            else:
                                                print()
                                                print("Incorrect")
                                                player3_turn = False
                                    else:
                                        would_guess3 = input("Would you like to guess the phrase? yes/no: ")
                                        if would_guess3 == "yes":
                                            full_guess3 = input("Guess the full phrase here!: ")
                                            if full_guess3 == phrase2:
                                                print()
                                                print("Congrats, you guessed the phrase!")
                                                print()
                                                print("That's the end of round 2!")
                                                buying_vowel = False
                                                round_2 = False
                                        else:
                                            buying_vowel = False
                                            player3_turn = False
                                            break
                            else:
                                print("Incorrect")
                                player3_turn = False
                else:
                    print("Please spin the wheel!")
    round_3 = True
    while round_3 and play:
        print()
        print("=====Welcome to Round 3!=====")
        print("=============================")
        print("Let's take a look at the scores!")
        print(Player1,"has",bank1)
        print(Player2,"has",bank2)
        print(Player3,"has",bank3)
        banks = [bank1,bank2,bank3]
        max_bank = max(banks)
        if max_bank == bank1:
            finalist = Player1
        elif max_bank == bank2:
            finalist = Player2
        else:
            finalist = Player3
        print()
        print("The player with the highest score gets to move on to the final round!")
        print("Welcome to the final round,",finalist,"!")
        print()
        print("The category for the final round is: Food & Drink")
        print("The word is 8 letters long!")
        print()
        guess_list3 = ["r","s","t","l","n","e"]
        guesses3 = ''
        print("You can guess 3 consonants and 1 vowel.")
        print("You must then guess the word.")
        print("Provided Letters: ",guess_list3)
        consanant_guesses = 3
        while consanant_guesses > 0:
            finalist_consonant_guess = input("Guess a consonant: ")
            if finalist_consonant_guess in guess_list3:
                print("That was already guessed!")
                finalist_consonant_guess = input("Guess a consonant: ")
            elif finalist_consonant_guess in vowel_list:
                print("That's a vowel! Please enter a consonant!")
                finalist_consonant_guess = input("Guess a consonant: ")
            guess_list3.append(finalist_consonant_guess)
            print("Previous Guesses:",guess_list3)
            while not finalist_consonant_guess.isalpha():
                print("Please enter a letter, not a number")
                finalist_consonant_guess = input("Guess a consonant: ")
            guesses3 += finalist_consonant_guess
            for char in list_of_letters3:
                if char in guess_list3:
                    print(char)  
                else:
                    print("_")
            if finalist_consonant_guess in list_of_letters3:
                print()
                print("Your guess is in the word!")
                consanant_guesses -= 1
            else:
                print()
                print("Your guess is not in the word.")
                consanant_guesses -= 1
        finalist_vowel_guess = input("Guess a vowel: ")
        if finalist_vowel_guess in guess_list3:
            print("That was already guessed!")
            finalist_vowel_guess = input("Guess a vowel: ")
        elif finalist_vowel_guess1 not in vowel_list:
            print("That's not a vowel!")
            finalist_vowel_guess1 = input("Guess a vowel!: ")
        guess_list3.append(finalist_vowel_guess)
        print("Previous Guesses:",guess_list3)
        while not finalist_vowel_guess.isalpha():
            print("Please enter a letter, not a number")
            finalist_vowel_guess = input("Guess a vowel: ")
        guesses3 += finalist_vowel_guess
        for char in list_of_letters3:
            if char in guess_list3:
                print(char)  
            else:
                print("_")
        if finalist_vowel_guess in list_of_letters3:
            print()
            print("Your guess is in the word!")
        else:
            print()
            print("Your guess is not in the word.")
        print()
        print("Time to guess the word!: ")
        finalist_full_guess = input("Please guess the full word here!: ")
        if finalist_full_guess == phrase3:
            print()
            print("Congratulations! You guessed the word correctly!")
            print("You win $10,000!")
            round_3 = False
            play = False
            break
        else:
            print()
            print("Sorry, that guess is incorrect.")
            print("Don't be too sad! You still get to take home the contents of your bank!")
            round_3 = False
            play = False
            break
print()
print("Thanks for playing Wheel of Fortune!")
# Out:
# =====Welcome to Wheel of Fortune!=====
# ...
# Please input the names of your players!
# Player 1 Name: Luke
# Player 2 Name: Dave
# Player 3 Name: Tom
#
# Welcome to the game Luke, Dave, and Tom!
#
# =====Welcome to Round 1!=====
# ...
#
# The Category for Round 1 is: Sports
#
# The phrase is 1 word long!
# The word has 8 letters!
#
#
# Luke it is your turn!
# Would you like to spin the wheel? yes/no: yes
# You stand to win $ 800
# Would you like to guess the phrase? yes/no: no
# Guessed Letters:  []
# Guess a consonant: a
# That's a vowel! Please enter a consonant!
# Guess a consonant: b
# Previous Guesses: ['b']
# b
# _
# _
# _
# b
# _
# _
# _
#
# Guessed Letters:  ['b']
# Would you like to buy a vowel for $250? yes/no: yes
# Guess a vowel!: t
# That's not a vowel!
